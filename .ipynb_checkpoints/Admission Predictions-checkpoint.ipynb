# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Machine-Learning-Model-for-Predicting-School-Admissions-from-an-Indian-Perspective" data-toc-modified-id="Machine-Learning-Model-for-Predicting-School-Admissions-from-an-Indian-Perspective-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Machine Learning Model for Predicting School Admissions from an Indian Perspective</a></span><ul class="toc-item"><li><span><a href="#About-this-dataset" data-toc-modified-id="About-this-dataset-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>About this dataset</a></span><ul class="toc-item"><li><span><a href="#Context" data-toc-modified-id="Context-1.1.1"><span class="toc-item-num">1.1.1&nbsp;&nbsp;</span>Context</a></span></li><li><span><a href="#Content" data-toc-modified-id="Content-1.1.2"><span class="toc-item-num">1.1.2&nbsp;&nbsp;</span>Content</a></span></li><li><span><a href="#Acknowledgements" data-toc-modified-id="Acknowledgements-1.1.3"><span class="toc-item-num">1.1.3&nbsp;&nbsp;</span>Acknowledgements</a></span></li><li><span><a href="#Inspiration" data-toc-modified-id="Inspiration-1.1.4"><span class="toc-item-num">1.1.4&nbsp;&nbsp;</span>Inspiration</a></span></li><li><span><a href="#Citation" data-toc-modified-id="Citation-1.1.5"><span class="toc-item-num">1.1.5&nbsp;&nbsp;</span>Citation</a></span></li></ul></li></ul></li><li><span><a href="#Import-Libraries" data-toc-modified-id="Import-Libraries-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Import Libraries</a></span></li><li><span><a href="#Read-dataset-and-display-columns" data-toc-modified-id="Read-dataset-and-display-columns-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Read dataset and display columns</a></span></li><li><span><a href="#Exploratory-Data-Analysis" data-toc-modified-id="Exploratory-Data-Analysis-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Exploratory Data Analysis</a></span><ul class="toc-item"><li><span><a href="#Describe-Data" data-toc-modified-id="Describe-Data-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Describe Data</a></span><ul class="toc-item"><li><span><a href="#Save-column-names-for-later-use" data-toc-modified-id="Save-column-names-for-later-use-4.1.1"><span class="toc-item-num">4.1.1&nbsp;&nbsp;</span>Save column names for later use</a></span></li></ul></li><li><span><a href="#Explore-Correlations-using-Seaborns-PairPlot" data-toc-modified-id="Explore-Correlations-using-Seaborns-PairPlot-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Explore Correlations using Seaborns PairPlot</a></span><ul class="toc-item"><li><span><a href="#Correlation-between-College-GPA-and-Chance-of-Admission-for-universities-rated-5." data-toc-modified-id="Correlation-between-College-GPA-and-Chance-of-Admission-for-universities-rated-5.-4.2.1"><span class="toc-item-num">4.2.1&nbsp;&nbsp;</span>Correlation between College GPA and Chance of Admission for universities rated 5.</a></span></li><li><span><a href="#Correlation-between-CGPA-and-Chance-of-Admit-for-all-University-Ratings" data-toc-modified-id="Correlation-between-CGPA-and-Chance-of-Admit-for-all-University-Ratings-4.2.2"><span class="toc-item-num">4.2.2&nbsp;&nbsp;</span>Correlation between CGPA and Chance of Admit for all University Ratings</a></span></li><li><span><a href="#Correlation-between-TOEFL-Score-and-Chance-of-Admit-for-all-University-Ratings" data-toc-modified-id="Correlation-between-TOEFL-Score-and-Chance-of-Admit-for-all-University-Ratings-4.2.3"><span class="toc-item-num">4.2.3&nbsp;&nbsp;</span>Correlation between TOEFL Score and Chance of Admit for all University Ratings</a></span></li><li><span><a href="#Correlation-between-GRE-Score-and-Chance-of-Admit-for-all-University-Ratings" data-toc-modified-id="Correlation-between-GRE-Score-and-Chance-of-Admit-for-all-University-Ratings-4.2.4"><span class="toc-item-num">4.2.4&nbsp;&nbsp;</span>Correlation between GRE Score and Chance of Admit for all University Ratings</a></span></li></ul></li></ul></li><li><span><a href="#Observations-for-examination-of-statistics" data-toc-modified-id="Observations-for-examination-of-statistics-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Observations for examination of statistics</a></span><ul class="toc-item"><li><span><a href="#Distribution-of-Chance-of-Admissions" data-toc-modified-id="Distribution-of-Chance-of-Admissions-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Distribution of Chance of Admissions</a></span></li><li><span><a href="#Distribution--of-School-Ratings" data-toc-modified-id="Distribution--of-School-Ratings-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Distribution  of School Ratings</a></span></li></ul></li><li><span><a href="#Variable-Selection-for-Predictive-Modeling" data-toc-modified-id="Variable-Selection-for-Predictive-Modeling-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Variable Selection for Predictive Modeling</a></span><ul class="toc-item"><li><span><a href="#Calculation-of-covariance-matrix" data-toc-modified-id="Calculation-of-covariance-matrix-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Calculation of covariance matrix</a></span></li><li><span><a href="#Selecting-Important-Variables" data-toc-modified-id="Selecting-Important-Variables-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Selecting Important Variables</a></span><ul class="toc-item"><li><span><a href="#Verifying-the-Shape-of-our-Data" data-toc-modified-id="Verifying-the-Shape-of-our-Data-6.2.1"><span class="toc-item-num">6.2.1&nbsp;&nbsp;</span>Verifying the Shape of our Data</a></span></li></ul></li><li><span><a href="#Scaling-the-X-Data" data-toc-modified-id="Scaling-the-X-Data-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>Scaling the X Data</a></span><ul class="toc-item"><li><span><a href="#Verify-the-scaling" data-toc-modified-id="Verify-the-scaling-6.3.1"><span class="toc-item-num">6.3.1&nbsp;&nbsp;</span>Verify the scaling</a></span></li><li><span><a href="#Check-for-Standard-Deviation" data-toc-modified-id="Check-for-Standard-Deviation-6.3.2"><span class="toc-item-num">6.3.2&nbsp;&nbsp;</span>Check for Standard Deviation</a></span></li></ul></li></ul></li><li><span><a href="#Calculate-the-PCA-Transformation" data-toc-modified-id="Calculate-the-PCA-Transformation-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Calculate the PCA Transformation</a></span><ul class="toc-item"><li><span><a href="#Fit-the-PCA-transformation-using-the-scaled-data." data-toc-modified-id="Fit-the-PCA-transformation-using-the-scaled-data.-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>Fit the PCA transformation using the scaled data.</a></span></li><li><span><a href="#Plot-the-cumulative-variance-ratio-with-number-of-components." data-toc-modified-id="Plot-the-cumulative-variance-ratio-with-number-of-components.-7.2"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>Plot the cumulative variance ratio with number of components.</a></span></li></ul></li><li><span><a href="#Linear-Regression-Ordinary-Least-Squares" data-toc-modified-id="Linear-Regression-Ordinary-Least-Squares-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Linear Regression Ordinary Least Squares</a></span><ul class="toc-item"><li><span><a href="#Verify-Feature-Columns" data-toc-modified-id="Verify-Feature-Columns-8.1"><span class="toc-item-num">8.1&nbsp;&nbsp;</span>Verify Feature Columns</a></span></li><li><span><a href="#Subset-X-and-Y,-Dropping-'Serial-Number'-from-X-Data" data-toc-modified-id="Subset-X-and-Y,-Dropping-'Serial-Number'-from-X-Data-8.2"><span class="toc-item-num">8.2&nbsp;&nbsp;</span>Subset X and Y, Dropping 'Serial Number' from X Data</a></span></li><li><span><a href="#Split-Data-into-Train-and-Test-Sets" data-toc-modified-id="Split-Data-into-Train-and-Test-Sets-8.3"><span class="toc-item-num">8.3&nbsp;&nbsp;</span>Split Data into Train and Test Sets</a></span></li><li><span><a href="#Fit-the-Model-and-Print-Summary" data-toc-modified-id="Fit-the-Model-and-Print-Summary-8.4"><span class="toc-item-num">8.4&nbsp;&nbsp;</span>Fit the Model and Print Summary</a></span></li><li><span><a href="#Make-Predictions-with-the-Model" data-toc-modified-id="Make-Predictions-with-the-Model-8.5"><span class="toc-item-num">8.5&nbsp;&nbsp;</span>Make Predictions with the Model</a></span></li><li><span><a href="#Compare-the-Predictions-with-Actual-Values" data-toc-modified-id="Compare-the-Predictions-with-Actual-Values-8.6"><span class="toc-item-num">8.6&nbsp;&nbsp;</span>Compare the Predictions with Actual Values</a></span></li><li><span><a href="#Compute-the-Mean-of-Differences-Between-Actual-and-Predicted-Values" data-toc-modified-id="Compute-the-Mean-of-Differences-Between-Actual-and-Predicted-Values-8.7"><span class="toc-item-num">8.7&nbsp;&nbsp;</span>Compute the Mean of Differences Between Actual and Predicted Values</a></span></li><li><span><a href="#Plot-our-Actual-vs.-Predicted-Values" data-toc-modified-id="Plot-our-Actual-vs.-Predicted-Values-8.8"><span class="toc-item-num">8.8&nbsp;&nbsp;</span>Plot our Actual vs. Predicted Values</a></span><ul class="toc-item"><li><span><a href="#Check-the-Root-Mean-Squared-Error" data-toc-modified-id="Check-the-Root-Mean-Squared-Error-8.8.1"><span class="toc-item-num">8.8.1&nbsp;&nbsp;</span>Check the Root Mean Squared Error</a></span></li></ul></li></ul></li><li><span><a href="#Lasso---Least-Absolute-Shrinkage-and-Selection-Operator" data-toc-modified-id="Lasso---Least-Absolute-Shrinkage-and-Selection-Operator-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Lasso - Least Absolute Shrinkage and Selection Operator</a></span><ul class="toc-item"><li><span><a href="#Subset-the-Data-and-Create-Train-Test-Subsets" data-toc-modified-id="Subset-the-Data-and-Create-Train-Test-Subsets-9.1"><span class="toc-item-num">9.1&nbsp;&nbsp;</span>Subset the Data and Create Train Test Subsets</a></span></li><li><span><a href="#Instanstiate-and-Fit-the-Model" data-toc-modified-id="Instanstiate-and-Fit-the-Model-9.2"><span class="toc-item-num">9.2&nbsp;&nbsp;</span>Instanstiate and Fit the Model</a></span></li><li><span><a href="#Evaluate-the-Model" data-toc-modified-id="Evaluate-the-Model-9.3"><span class="toc-item-num">9.3&nbsp;&nbsp;</span>Evaluate the Model</a></span></li><li><span><a href="#Lasso-hyperparameter-tuning" data-toc-modified-id="Lasso-hyperparameter-tuning-9.4"><span class="toc-item-num">9.4&nbsp;&nbsp;</span>Lasso hyperparameter tuning</a></span></li><li><span><a href="#Lasso-tuned" data-toc-modified-id="Lasso-tuned-9.5"><span class="toc-item-num">9.5&nbsp;&nbsp;</span>Lasso tuned</a></span></li></ul></li><li><span><a href="#Ordinary-Least-Squares-Using-Fewer-Features" data-toc-modified-id="Ordinary-Least-Squares-Using-Fewer-Features-10"><span class="toc-item-num">10&nbsp;&nbsp;</span>Ordinary Least Squares Using Fewer Features</a></span><ul class="toc-item"><li><span><a href="#Subset-our-data" data-toc-modified-id="Subset-our-data-10.1"><span class="toc-item-num">10.1&nbsp;&nbsp;</span>Subset our data</a></span></li><li><span><a href="#Create-Train-Test-Split" data-toc-modified-id="Create-Train-Test-Split-10.2"><span class="toc-item-num">10.2&nbsp;&nbsp;</span>Create Train Test Split</a></span></li><li><span><a href="#Instantiate,-Fit-and-Evaluate-our-Model" data-toc-modified-id="Instantiate,-Fit-and-Evaluate-our-Model-10.3"><span class="toc-item-num">10.3&nbsp;&nbsp;</span>Instantiate, Fit and Evaluate our Model</a></span></li><li><span><a href="#Create-Predictions" data-toc-modified-id="Create-Predictions-10.4"><span class="toc-item-num">10.4&nbsp;&nbsp;</span>Create Predictions</a></span></li><li><span><a href="#Plot-Predictions-against-Acutal-Admission-Values" data-toc-modified-id="Plot-Predictions-against-Acutal-Admission-Values-10.5"><span class="toc-item-num">10.5&nbsp;&nbsp;</span>Plot Predictions against Acutal Admission Values</a></span></li><li><span><a href="#Check-the-Root-Mean-Squared-Error" data-toc-modified-id="Check-the-Root-Mean-Squared-Error-10.6"><span class="toc-item-num">10.6&nbsp;&nbsp;</span>Check the Root Mean Squared Error</a></span></li></ul></li><li><span><a href="#Conclusion" data-toc-modified-id="Conclusion-11"><span class="toc-item-num">11&nbsp;&nbsp;</span>Conclusion</a></span><ul class="toc-item"><li><span><a href="#Using-less-data-is-less-accurate" data-toc-modified-id="Using-less-data-is-less-accurate-11.1"><span class="toc-item-num">11.1&nbsp;&nbsp;</span>Using less data is less accurate</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Machine Learning Model for Predicting School Admissions from an Indian Perspective

# %% [markdown]
# ## About this dataset
#
# ### Context
# This dataset is created for prediction of Graduate Admissions from an Indian perspective.
#
# ### Content
# The dataset contains several parameters which are considered important during the application for Masters Programs.
# The parameters included are :
#
# GRE Scores ( out of 340 )
# TOEFL Scores ( out of 120 )
# University Rating ( out of 5 )
# Statement of Purpose and Letter of Recommendation Strength ( out of 5 )
# Undergraduate GPA ( out of 10 )
# Research Experience ( either 0 or 1 )
# Chance of Admit ( ranging from 0 to 1 )
#
# ### Acknowledgements
# This dataset is inspired by the UCLA Graduate Dataset. The test scores and GPA are in the older format.
# The dataset is owned by Mohan S Acharya.
#
# ### Inspiration
# This dataset was built with the purpose of helping students in shortlisting universities with their profiles. The predicted output gives them a fair idea about their chances for a particular university.
#
# ### Citation
# Please cite the following if you are interested in using the dataset :
# Mohan S Acharya, Asfia Armaan, Aneeta S Antony : A Comparison of Regression Models for Prediction of Graduate Admissions, IEEE International Conference on Computational Intelligence in Data Science 2019
#
# I would like to thank all of you for contributing to this dataset through discussions and questions. I am in awe of the number of kernels built on this dataset. Some results and visualisations are fantastic and makes me a proud owner of the dataset. Keep em' coming! Thank You.

# %% [markdown]
# # Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm

from sklearn.linear_model import Lasso
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, scale
from sklearn.decomposition import PCA
from pandas_profiling import ProfileReport

# %% [markdown]
# # Read dataset and display columns

# %%
admit_data = pd.read_csv("Admission_Predict.csv")
admit_data.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        324          107                  4  4.0   4.5  8.87
# 2           3        316          104                  3  3.0   3.5  8.00
# 3           4        322          110                  3  3.5   2.5  8.67
# 4           5        314          103                  2  2.0   3.0  8.21
#
#    Research  Chance of Admit
# 0         1              0.92
# 1         1              0.76
# 2         1              0.72
# 3         1              0.80
# 4         0              0.65

# %% [markdown]
# # Exploratory Data Analysis
# ## Describe Data

# %%
admit_data.describe().T
# Out:
#                    count        mean         std     min     25%     50%  \
# Serial No.         400.0  200.500000  115.614301    1.00  100.75  200.50
# GRE Score          400.0  316.807500   11.473646  290.00  308.00  317.00
# TOEFL Score        400.0  107.410000    6.069514   92.00  103.00  107.00
# University Rating  400.0    3.087500    1.143728    1.00    2.00    3.00
# SOP                400.0    3.400000    1.006869    1.00    2.50    3.50
# LOR                400.0    3.452500    0.898478    1.00    3.00    3.50
# CGPA               400.0    8.598925    0.596317    6.80    8.17    8.61
# Research           400.0    0.547500    0.498362    0.00    0.00    1.00
# Chance of Admit    400.0    0.724350    0.142609    0.34    0.64    0.73
#
#                         75%     max
# Serial No.         300.2500  400.00
# GRE Score          325.0000  340.00
# TOEFL Score        112.0000  120.00
# University Rating    4.0000    5.00
# SOP                  4.0000    5.00
# ...

# %% [markdown]
# __Looking at the table above we see that we have 400 entries and no missing data__

# %% [markdown]
# ### Save column names for later use

# %%
cols = admit_data.columns.tolist()
print(cols)
# Out:
# ['Serial No.', 'GRE Score', 'TOEFL Score', 'University Rating', 'SOP', 'LOR ', 'CGPA', 'Research', 'Chance of Admit ']

# %% [markdown]
# ## Explore Correlations using Seaborns PairPlot
# The varying colors in the plots are the university ratings, from dark for the lowest rating, to light for the highest rating.
# The well organized clusters, such as those found at the junction of CGPA and Chance of Admit, show a strong correlation, as well as distinct clustering of school ratings.

# %%
sns.pairplot(admit_data[cols], hue='University Rating', palette='rocket', height=2.0);
plt.savefig('Graphics/PairPlot.png')

# %% [markdown]
# ### Correlation between College GPA and Chance of Admission for universities rated 5.
# The correlation is very clear between CGPA and chance of admission.

# %%
sns.set_style('whitegrid')
sns.lmplot(x='CGPA', y='Chance of Admit ', hue='University Rating', 
           data=admit_data.loc[admit_data['University Rating'] == 5], height=6);
plt.savefig('Graphics/CGPAUni5.png')

# %% [markdown]
# ### Correlation between CGPA and Chance of Admit for all University Ratings

# %%
sns.set_style('whitegrid')
sns.lmplot(x='CGPA', y='Chance of Admit ', hue='University Rating', 
           data=admit_data, height=6);
plt.savefig('Graphics/CGPA.png')

# %% [markdown]
# ### Correlation between TOEFL Score and Chance of Admit for all University Ratings

# %%
sns.lmplot(x='TOEFL Score', y='Chance of Admit ', hue='University Rating', data=admit_data, height=6)
plt.savefig('Graphics/TOEFL.png')

# %% [markdown]
# ### Correlation between GRE Score and Chance of Admit for all University Ratings

# %%
sns.lmplot(x='GRE Score', y='Chance of Admit ', hue='University Rating', data=admit_data, height=6)
plt.savefig('Graphics/GRE.png')

# %% [markdown]
# # Observations for examination of statistics
#
# Looking at the Chance of Admission row we see a strong corelation between test scores, statement of purpose, and letter of recomendation, but less of a corelation with research experience.
#
# The histogram at the end of the row shows the typical chance of admission to be about 70% with more weight toward the higher chance of admission.
#
# Our data is on different scales, with the lower scales as 1 to 5 and the higher upto 0 to 340, the variables will have to be brought to the same scale with either standadization or normalization before our regression model is built.

# %% [markdown]
# ## Distribution of Chance of Admissions

# %%
sns.displot(admit_data['Chance of Admit '], bins=20, kde=True)
plt.savefig('Graphics/AdmitDist.png')
plt.show()

# %% [markdown]
# ## Distribution  of School Ratings

# %%
sns.displot(admit_data['University Rating'], bins=5, kde=True)
plt.savefig('Graphics/SchRatDist.png')
plt.show()

# %% [markdown]
# # Variable Selection for Predictive Modeling

# %% [markdown]
# ## Calculation of covariance matrix

# %%
stdsc = StandardScaler()
X_std = stdsc.fit_transform(admit_data[cols].iloc[:,range(0,9)].values)
cov_mat = np.cov(X_std.T)
plt.figure(figsize=(10,10))
sns.set(font_scale=1.5)
hm = sns.heatmap(cov_mat, cbar=True, annot=True, square=True, fmt='.2f', annot_kws={'size':12}, yticklabels=cols, xticklabels=cols)
plt.title('Covariance Matrix')
plt.tight_layout()
plt.savefig('Graphics/CovMat.png')
plt.show()

# %% [markdown]
# ## Selecting Important Variables
#
# From the covariance matrix above we the the Admit variable correlates the strongest with the variables: CGPA, GRE Score and TOEFL Score, and less with the variables: University Rating, SOP and LOR.
#
# For our initial modeling we are going to use all of the features of our data set.

# %%
cols_selected = ['GRE Score', 'TOEFL Score', 'University Rating', 'SOP', 'LOR ', 'CGPA', 'Chance of Admit ']
admit_data[cols_selected].head()
# Out:
#    GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0        337          118                  4  4.5   4.5  9.65
# 1        324          107                  4  4.0   4.5  8.87
# 2        316          104                  3  3.0   3.5  8.00
# 3        322          110                  3  3.5   2.5  8.67
# 4        314          103                  2  2.0   3.0  8.21
#
#    Chance of Admit
# 0              0.92
# 1              0.76
# 2              0.72
# 3              0.80
# 4              0.65

# %%
admit_data_X = admit_data[cols_selected].iloc[:,0:8].values     # Features Matrix
admit_data_y = admit_data[cols_selected]['Chance of Admit ']    # Target Variable

# %% [markdown]
# ### Verifying the Shape of our Data
# We see that we have 400 rows of 7 features.

# %%
admit_data_X.shape
# Out:
# (400, 7)

# %%
admit_data_y.shape
# Out:
# (400,)

# %% [markdown]
# ## Scaling the X Data
#
# Our data is on different scales, with the lower scales as 1 to 5 and the higher upto 0 to 340, the variables will have to be brought to the same scale with standadization. This will center to the mean and scale to unit variance.

# %%
admit_X_scaled = scale(admit_data_X)

# %% [markdown]
# ### Verify the scaling
#
# We can test to see that the scaling centered to the mean.

# %%
admit_X_scaled.mean().round(2)
# Out:
# 0.0

# %% [markdown]
# ### Check for Standard Deviation
#
# We'll perform a similar check using panda's std() method.

# %%
admit_X_scaled.std(ddof=0)
# Out:
# 1.0

# %% [markdown]
# # Calculate the PCA Transformation
#
# ## Fit the PCA transformation using the scaled data.

# %%
admit_pca = PCA().fit(admit_X_scaled)

# %% [markdown]
# ## Plot the cumulative variance ratio with number of components.

# %%
plt.subplots(figsize=(10,8))
plt.plot(admit_pca.explained_variance_ratio_.cumsum())
plt.plot(admit_pca.explained_variance_ratio_)
plt.xlabel('Component #')
plt.xticks([0, 1, 2, 3, 4, 5, 6,],['1', '2', '3', '4', '5', '6', '7'])
plt.ylabel('Cumulative Ratio Variance')
plt.title('Cumulative Variance Ratio explained by PCA components')
plt.legend(['Cumulative Sum', 'Variance Ratio']);

# %% [markdown]
# Looking at the plot above we can see that the first two Principle Components  account for about 85% of our variance in the Cumulative Sum. We can also see that there is a distinct 'elbow' the plot of variance ratio between component 2 and 3, telling us that components 3 thru 7 are much less important than components 1 and 2.

# %% [markdown]
# # Linear Regression Ordinary Least Squares
# ## Verify Feature Columns

# %%
# Check data shapes
admit_data.columns
# Out:
# Index(['Serial No.', 'GRE Score', 'TOEFL Score', 'University Rating', 'SOP',
#        'LOR ', 'CGPA', 'Research', 'Chance of Admit '],
#       dtype='object')

# %% [markdown]
# ## Subset X and Y, Dropping 'Serial Number' from X Data

# %%
# Choose X and Y data sets
X = admit_data.drop(['Serial No.', 'Chance of Admit '], axis=1)
y = admit_data['Chance of Admit ']

# %% [markdown]
# ## Split Data into Train and Test Sets
# Our test set size is 33%

# %%
# Splitting the data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.33, random_state=10)

# Check shapes
print(X_train.shape, X_test.shape)
print(y_train.shape, y_test.shape)
# Out:
# (268, 7) (132, 7)
# (268,) (132,)

# %% [markdown]
# ## Fit the Model and Print Summary
# The model fits well, the R-squared score is 0.991.

# %%
# Create the model
rModel = sm.OLS(y_train, X_train)

# Fit the model
rModel_fit = rModel.fit()

# Evaluate the model
rModel_fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:       Chance of Admit    R-squared (uncentered):                   0.991
# Model:                            OLS   Adj. R-squared (uncentered):              0.991
# Method:                 Least Squares   F-statistic:                              4162.
# Date:                Tue, 30 Mar 2021   Prob (F-statistic):                   1.07e-263
# Time:                        04:43:02   Log-Likelihood:                          334.47
# No. Observations:                 268   AIC:                                     -654.9
# Df Residuals:                     261   BIC:                                     -629.8
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %% [markdown]
# ## Make Predictions with the Model

# %%
# Make predictions
y_pred = rModel_fit.predict(X_test)

# %% [markdown]
# ## Compare the Predictions with Actual Values

# %%
# Combine the predictions and actual values into a data frame
pred_act = pd.DataFrame(y_test)
pred_act['Predicted Admit'] = y_pred
pred_act['Difference'] = (pred_act['Chance of Admit '] - pred_act['Predicted Admit']).round(2)
pred_act.sample(10).sort_values(by=['Difference'])
# Out:
#      Chance of Admit   Predicted Admit  Difference
# 10               0.52         0.702154       -0.18
# 377              0.47         0.532620       -0.06
# 152              0.86         0.890245       -0.03
# 208              0.64         0.633297        0.01
# 192              0.86         0.852820        0.01
# 121              0.94         0.917617        0.02
# 238              0.70         0.681377        0.02
# 357              0.68         0.657714        0.02
# 195              0.78         0.738617        0.04
# 6                0.75         0.690695        0.06

# %% [markdown]
# ## Compute the Mean of Differences Between Actual and Predicted Values
# __Our average error in our predictions is 0.6%, less than 1%, that's not bad.__

# %%
round(pred_act.Difference.mean(), 4)
# Out:
# -0.0066

# %% [markdown]
# ## Plot our Actual vs. Predicted Values

# %%
plt.figure(figsize=(10,10))
sns.regplot(x='Chance of Admit ', y='Predicted Admit', data=pred_act)
plt.xlabel('Actual Chance of Admission')
plt.ylabel('Predicted Chance of Admission');
plt.savefig('Graphics/PredAdmit.png')

# %% [markdown]
# ### Check the Root Mean Squared Error
#
# The RMSE tells us how far, on average, our predictions were mistaken. An RMSE of 0 would mean we were making perfect predictions.

# %%
# Define a function to check the RMSE.
import math
from sklearn.metrics import mean_squared_error, r2_score 

def rmse(actual, predicted):
    return math.sqrt(mean_squared_error(actual, predicted))

round(rmse(pred_act['Chance of Admit '], pred_act['Predicted Admit']),4)
# Out:
# 0.0748

# %% [markdown]
# # Lasso - Least Absolute Shrinkage and Selection Operator
# The Lasso model is a linear regression model that performs both variable selection and regularization in an effort to enhance the prediction accuracy and interpretability of the model.

# %% [markdown]
# ## Subset the Data and Create Train Test Subsets

# %%
# Choose X and Y data sets
X = admit_data.drop(['Serial No.', 'Chance of Admit '], axis=1)
y = admit_data['Chance of Admit ']

# Split data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.33, random_state=10)

# %% [markdown]
# ## Instanstiate and Fit the Model

# %%
# Create the model
reg = Lasso(alpha=0.1)

# Fit the model
reg_fit = reg.fit(X_train, y_train)

# %% [markdown]
# ## Evaluate the Model

# %%
# Evaluate the model
print('Independent term in decision fuction:',reg_fit.intercept_)

# Predict
y_pred_lasso = reg.predict(X_test)

# Return R^2
print('Coefficienct of determination R^2 of the prediction:',reg.score(X_test, y_test))
# Out:
# Independent term in decision fuction: -2.1299375273747017
# Coefficienct of determination R^2 of the prediction: 0.6265021178092192

# %% [markdown]
# The coefficient __R^2__ is defined as (1 - u/v), where u is the residual sum of squares ((y_true - y_pred) ** 2).sum() and v is the total sum of squares ((y_true - y_true.mean()) ** 2).sum(). __The best possible score is 1.0__ and it can be negative (because the model can be arbitrarily worse). A constant model that always predicts the expected value of y, disregarding the input features, would get a R^2 score of 0.0.

# %% [markdown]
# ## Lasso hyperparameter tuning
# We are testing various alpha values to tune our model for accuracy.

# %%
from sklearn.model_selection import GridSearchCV

# Create an array of alpha values for testing
alphas = np.array([5, 0.5, 0.05, 0.005, 0.0005, 1 , 0.1, 0.01, 0.001, 0.0001,])

# Instantiate model
reg = Lasso()
grid = GridSearchCV(estimator=reg, param_grid=dict(alpha=alphas))

# Fit model
grid.fit(X_train, y_train)

# Return scores
print(grid.best_estimator_.alpha)
print(grid.best_score_)
# Out:
# 0.001
# 0.8072072435166028

# %% [markdown]
# ## Lasso tuned

# %%
# Create the model
reg = Lasso(alpha=0.001)

# Fit the model
reg_fit = reg.fit(X_train, y_train)

# Evaluate the model
print('Independent term in decision fuction:',reg_fit.intercept_)

# Predict
y_pred_lasso = reg.predict(X_test)

# Return R^2
print('Coefficienct of determination R^2 of the prediction:',reg.score(X_test, y_test))
# Out:
# Independent term in decision fuction: -1.4204560426695876
# Coefficienct of determination R^2 of the prediction: 0.7531425195238023

# %% [markdown]
# __Our Lasso model did not produce useable results, especially when compared to our OLS model.__
# We are going to try our OLS model again using less features to determine if all of the features are important to our model.

# %% [markdown]
# # Ordinary Least Squares Using Fewer Features
# We are going to run a OLS model on only four features; GRE Score, TOEFL Score and CGPA
# ## Subset our data

# %%
# Choose X and Y data sets
X = admit_data[['GRE Score', 'TOEFL Score', 'CGPA']]
y = admit_data[['Chance of Admit ']]

# %% [markdown]
# ## Create Train Test Split

# %%
# Splitting the data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.33)

# Check shapes
print(X_train.shape, X_test.shape)
print(y_train.shape, y_test.shape)
# Out:
# (268, 3) (132, 3)
# (268, 1) (132, 1)

# %% [markdown]
# ## Instantiate, Fit and Evaluate our Model

# %%
# Create the model
rModel = sm.OLS(y_train, X_train)

# Fit the model
rModel_fit = rModel.fit()

# Evaluate the model
rModel_fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:       Chance of Admit    R-squared (uncentered):                   0.988
# Model:                            OLS   Adj. R-squared (uncentered):              0.988
# Method:                 Least Squares   F-statistic:                              7194.
# Date:                Tue, 30 Mar 2021   Prob (F-statistic):                   1.66e-253
# Time:                        04:43:02   Log-Likelihood:                          294.32
# No. Observations:                 268   AIC:                                     -582.6
# Df Residuals:                     265   BIC:                                     -571.9
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# ...

# %% [markdown]
# ## Create Predictions

# %%
# Let's use our new model to make predictions of the dependent variable y.
y_pred = rModel_fit.predict(X_test)

# Combine the predictions and actual values into a data frame
pred_act = pd.DataFrame(y_test)
pred_act['Predicted Admit'] = y_pred
pred_act['Difference'] = (pred_act['Chance of Admit '] - pred_act['Predicted Admit']).round(2)
pred_act.sample(10).sort_values(by=['Difference'])
# Out:
#      Chance of Admit   Predicted Admit  Difference
# 110              0.61         0.766771       -0.16
# 225              0.61         0.671757       -0.06
# 326              0.63         0.658776       -0.03
# 1                0.76         0.745852        0.01
# 197              0.73         0.697891        0.03
# 133              0.79         0.756741        0.03
# 252              0.71         0.671002        0.04
# 337              0.94         0.888633        0.05
# 338              0.81         0.728019        0.08
# 49               0.78         0.648391        0.13

# %% [markdown]
# ## Plot Predictions against Acutal Admission Values

# %%
plt.figure(figsize=(10,10))
sns.regplot(x='Chance of Admit ', y='Predicted Admit', data=pred_act)
plt.ylim(0.35, 1)
plt.xlim(0.35, 1)
plt.xlabel('Actual Chance of Admission')
plt.ylabel('Predicted Chance of Admission');
plt.savefig('Graphics/PredAdmit2.png')

# %% [markdown]
# ## Check the Root Mean Squared Error
# The RMSE tells us how far, on average, our predictions were mistaken. An RMSE of 0 would mean we were making perfect predictions.

# %%
round(rmse(pred_act['Chance of Admit '], pred_act['Predicted Admit']),4)
# Out:
# 0.0865

# %% [markdown]
# # Conclusion
# ## Using less data is less accurate
# R Squared difference 0.99 vs. 0.98
# RMSE difference 0.06 vs. 0.08
